# %% [markdown]
# API NOMINATIM

# %% [markdown]
# Import lib

# %%
import requests
import pandas as pd
import json
import csv
import os

# %% [markdown]
# Connection api

# %%
url_nominatim = "https://nominatim.openstreetmap.org/search"

# %%
villes = [
    "Mont Saint Michel",
    "St Malo",
    "Bayeux",
    "Le Havre",
    "Rouen",
    "Paris",
    "Amiens",
    "Lille",
    "Strasbourg",
    "Chateau du Haut Koenigsbourg",
    "Colmar",
    "Eguisheim",
    "Besancon",
    "Dijon",
    "Annecy",
    "Grenoble",
    "Lyon",
    "Gorges du Verdon",
    "Bormes les Mimosas",
    "Cassis",
    "Marseille",
    "Aix en Provence",
    "Avignon",
    "Uzes",
    "Nimes",
    "Aigues Mortes",
    "Saintes Maries de la mer",
    "Collioure",
    "Carcassonne",
    "Ariege",
    "Toulouse",
    "Montauban",
    "Biarritz",
    "Bayonne",
    "La Rochelle"
    ]

# %%
def get_gps_data(city):

    params = {
        "q": city,
        "format": "json",
    }

    response = requests.get(url_nominatim, params=params)

    # Vérification du statut de la requête
    if response.status_code == 200:

        data = response.json()

        # Extraction des données GPS
        if data: 
            latitude = data[0]["lat"]
            longitude = data[0]["lon"]
        else:
            latitude = ""  # Remplacer None par une chaîne vide
            longitude = ""  

        print(f"Ville : {city}")
        print(f"Latitude : {latitude}")
        print(f"Longitude : {longitude}")
        
        return latitude, longitude  
    else:
        print(f"Erreur : {response.status_code}")
        return None, None

csv_filename = "gps_data.csv"

# Si le fichier CSV n'existe pas
if not os.path.exists(csv_filename):
    with open(csv_filename, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Ville", "Latitude", "Longitude"])

# Ouvrir le fichier CSV 
with open(csv_filename, "a", newline="") as csvfile:
    writer = csv.writer(csvfile)
    
    # Itérer sur les villes
    for ville in villes:
        # Extraire les données GPS
        latitude, longitude = get_gps_data(ville)
        
        # Préparer les données pour le fichier CSV
        csv_data = [ville, latitude, longitude]

        # Écrire la ligne de données
        writer.writerow(csv_data)
# Out:
# Ville : Mont Saint Michel
# Latitude : 48.6359541
# Longitude : -1.511459954959514
# Ville : St Malo
# Latitude : 49.314695
# Longitude : -96.9538228
# Ville : Bayeux
# Latitude : 49.2764624
# Longitude : -0.7024738
# Ville : Le Havre
# Latitude : 49.4938975
# Longitude : 0.1079732
# Ville : Rouen
# Latitude : 49.4404591
# Longitude : 1.0939658
# Ville : Paris
# Latitude : 48.8534951
# Longitude : 2.3483915
# Ville : Amiens
# Latitude : 49.8941708
# Longitude : 2.2956951
# Ville : Lille
# Latitude : 50.6365654
# Longitude : 3.0635282
# Ville : Strasbourg
# Latitude : 48.584614
# Longitude : 7.7507127
# Ville : Chateau du Haut Koenigsbourg
# Latitude : 48.2493154
# Longitude : 7.3429403075238096
# Ville : Colmar
# Latitude : 48.0777517
# Longitude : 7.3579641
# Ville : Eguisheim
# Latitude : 48.0447968
# Longitude : 7.3079618
# Ville : Besancon
# Latitude : 47.2380222
# Longitude : 6.0243622
# Ville : Dijon
# Latitude : 47.3215806
# Longitude : 5.0414701
# Ville : Annecy
# Latitude : 45.8992348
# Longitude : 6.1288847
# Ville : Grenoble
# Latitude : 45.1875602
# Longitude : 5.7357819
# Ville : Lyon
# Latitude : 45.7578137
# Longitude : 4.8320114
# Ville : Gorges du Verdon
# Latitude : 43.7496562
# Longitude : 6.3285616
# Ville : Bormes les Mimosas
# Latitude : 43.1506968
# Longitude : 6.3419285
# Ville : Cassis
# Latitude : 43.2140359
# Longitude : 5.5396318
# Ville : Marseille
# Latitude : 43.2961743
# Longitude : 5.3699525
# Ville : Aix en Provence
# Latitude : 43.5298424
# Longitude : 5.4474738
# Ville : Avignon
# Latitude : 43.9492493
# Longitude : 4.8059012
# Ville : Uzes
# Latitude : 44.0121279
# Longitude : 4.4196718
# Ville : Nimes
# Latitude : 43.8374249
# Longitude : 4.3600687
# Ville : Aigues Mortes
# Latitude : 43.5661521
# Longitude : 4.19154
# Ville : Saintes Maries de la mer
# Latitude : 43.4515922
# Longitude : 4.4277202
# Ville : Collioure
# Latitude : 42.52505
# Longitude : 3.0831554
# Ville : Carcassonne
# Latitude : 43.2130358
# Longitude : 2.3491069
# Ville : Ariege
# Latitude : 42.9455368
# Longitude : 1.4065544156065486
# Ville : Toulouse
# Latitude : 43.6044622
# Longitude : 1.4442469
# Ville : Montauban
# Latitude : 44.0175835
# Longitude : 1.3549991
# Ville : Biarritz
# Latitude : 43.471143749999996
# Longitude : -1.552726590666314
# Ville : Bayonne
# Latitude : 43.4945144
# Longitude : -1.4736657
# Ville : La Rochelle
# Latitude : 46.1591126
# Longitude : -1.1520434

# %%
df = pd.read_csv("gps_data.csv")
df.head()
# Out:
#                Ville   Latitude  Longitude
# 0  Mont Saint Michel  48.635954  -1.511460
# 1            St Malo  49.314695 -96.953823
# 2             Bayeux  49.276462  -0.702474
# 3           Le Havre  49.493898   0.107973
# 4              Rouen  49.440459   1.093966

# %%
print(df)
# Out:
#                 Ville   Latitude  Longitude
# 0   Mont Saint Michel  48.635954  -1.511460
# 1             St Malo  49.314695 -96.953823
# 2              Bayeux  49.276462  -0.702474
# 3            Le Havre  49.493898   0.107973
# 4               Rouen  49.440459   1.093966
# ..                ...        ...        ...
# 65           Toulouse  43.604462   1.444247
# 66          Montauban  44.017584   1.354999
# 67           Biarritz  43.471144  -1.552727
# 68            Bayonne  43.494514  -1.473666
# 69        La Rochelle  46.159113  -1.152043
#
# [70 rows x 3 columns]
